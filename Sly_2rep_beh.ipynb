# %% [markdown]
# Sly 202321103 performance

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231103_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]
print(cond_performance_ordered)
colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')

csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\434529283.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)
# [0.5, 0.5714285714285714, 0.625, 0.45454545454545453, 1.0, 0.75, 1.0, 0.8888888888888888, 1.0, 1.0, 1.0, 0.7272727272727273, 0.6666666666666666, 0.9, 1.0, 1.0]

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231031_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]

colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')

csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\1807793365.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231107_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]

colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')
csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\3677474615.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\3677474615.py:31: RuntimeWarning: invalid value encountered in divide
#   cond_performance = correct_cond / overall_cond

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231026_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]

colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')

csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\2131194980.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231025_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]

colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')

csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\3177134290.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231113_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]

colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')

csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\2842288712.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231115_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]

colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')

csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\2447316772.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)

# %%
import numpy as np
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt

# Load data
name = "20231116_Sly_MMN_steps.mat"
dict_path = r'D:\Uchi_data\Sly_beh\MMN_data\converted_data\\'
filename = dict_path + name
data = scipy.io.loadmat(filename)

beh = data['beh'][0]
beh_df = pd.DataFrame(beh)

num_cond = int(beh_df['Condition'].max())  # Ensure num_cond is an integer

overall_cond = np.zeros(num_cond)
correct_cond = np.zeros(num_cond)
RT_cond = np.full((num_cond, 200), np.nan)

for _, row in beh_df.iterrows():
    for i in range(1, num_cond + 1):  # MATLAB indices start from 1
        if row['Condition'] == i and (row['TrialError'] == 0 or row['TrialError'] == 8):
            overall_cond[i-1] += 1  # Adjust for 0-based indexing

            if row['TrialError'] == 0:
                correct_cond[i-1] += 1
                RT_cond[i-1, int(correct_cond[i-1])-1] = row['ReactionTime']

mean_RT = np.nanmean(RT_cond, axis=1)
cond_performance = correct_cond / overall_cond


plt.figure()
order = [9, 12, 8, 7, 10, 11, 5, 6, 13, 15, 4, 2, 14, 16, 1, 3]
cond_performance_ordered = [cond_performance[i-1] for i in order]

colors = ['lightgreen' if i in [1, 2, 5, 6, 9, 10, 13, 14] else 'lightblue' for i in range(1, 17)]

bars = plt.bar(range(1, 17), cond_performance_ordered, color=colors)
plt.xlabel('Conditions')
plt.ylabel('Performance')
plt.title('Performance ' + name)

# Adding legend with specific color
handles = [plt.Line2D([0], [0], color='lightgreen', lw=4),
           plt.Line2D([0], [0], color='lightblue', lw=4)]

labels = ['Match trials', 'Nonmatch trials']

plt.legend(handles, labels, loc='upper left')

csv_filename = 'cond_performance_ordered.csv'
df = pd.DataFrame({'Condition Order': order, 'Performance': cond_performance_ordered})
df.to_csv(csv_filename, index=False)
# Out:
# C:\Users\Sihai\AppData\Local\Temp\ipykernel_12932\1638250778.py:30: RuntimeWarning: Mean of empty slice
#   mean_RT = np.nanmean(RT_cond, axis=1)

# %% [markdown]
# Performance trend across sessions

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is the DataFrame containing the data from your spreadsheet
# You would load the data from your actual file. 
# For this example, I'll create a DataFrame based on the structure you've provided:
data = {
    'Performance_1025': [0.674603175, 0.837662338, 0.622222222, 0.95, 0.6, 0.694444444, 0.818181818, 0.817460317],
    'Performance_1026': [0.375, 0.770833333, 0.857142857, 1, 0.558441558, 0.863636364, 0.404761905, 0.878205128],
    'Performance_1031': [0.531746032, 0.713636364, 0.808333334, 1, 0.5625, 0.866071429, 0.431818182, 0.7],
    'Performance_1103': [0.535714286, 0.539772727, 0.875, 0.944444444, 1, 0.863636364, 0.783333333, 1],
    'Performance_1107': [0.388888889, 0.125, 1, 0.85, 0.777777778, 0.8, 1, 1]
}
df = pd.DataFrame(data, index=['C11_Match', 'C11_NonMatch', 'C12_Match', 'C12_NonMatch', 
                               'C21_Match', 'C21_NonMatch', 'C22_Match', 'C22_NonMatch'])

# Plotting
plt.figure(figsize=(12, 6))

# We will use these colors to differentiate between Match and NonMatch
colors = {'Match': 'green', 'NonMatch': 'blue'}

# Convert the days to categorical data points
day_labels = [col.split('_')[1] for col in df.columns if 'Performance' in col]
days = range(len(day_labels))

# Separate Match and NonMatch for plotting
for condition in df.index:
    match_type = condition.split('_')[1]
    plt.plot(days, df.loc[condition], label=condition, color=colors[match_type], marker='o')

plt.xlabel('Day')
plt.ylabel('Performance')
plt.title('Performance Trends Across Days')
plt.xticks(days, day_labels)  # Set the x-axis with the day labels
plt.legend()
plt.grid(True)
plt.show()
